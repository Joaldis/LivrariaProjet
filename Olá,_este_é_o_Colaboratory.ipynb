# %% [markdown]
# <a href="https://colab.research.google.com/github/Joaldis/LivrariaProjet/blob/main/Ol%C3%A1%2C_este_%C3%A9_o_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def custo (T4):

  C = 86400/(T4-30)+8820/(270-T4)**0.5
  return C

# %%
custo(50)
# Out:
# 4914.64427869258

# %%
import matplotlib.pyplot as plt
import numpy as np
T4 = np.linspace(30,270,100)
C = custo(T4)
plt.plot(T4,C)
# Out:
# <ipython-input-9-5ab1838d6754>:3: RuntimeWarning: divide by zero encountered in divide
#   C = 86400/(T4-30)+8820/(270-T4)**0.5

# %%
li= 30
ls = 270
delta= li-ls
tol = 1
while delta > tol:
    xi = li + 0.382*delta
    x2 = ls - 0.382*delta
    fi = custo(xi)
    fs = custo(xs)
  if fi > fs
      li = xi
      xi = xs
      fi=fs
  else:
   ls=xs
   xs=xi
   fs=fi

print(x1)
# Out:
#   File "<tokenize>", line 10
#     if fi > fs
#     ^
# IndentationError: unindent does not match any outer indentation level
